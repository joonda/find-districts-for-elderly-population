# %% [markdown]
# * 국내 노인 여가시설 데터
#     * https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=440b1d1f-9000-41d4-be5f-695d2d3ae27b

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
import warnings
import os

if os.name == 'nt':
    print("This is a Windows environment.")
    rc('font', family='Malgun Gothic')
elif os.name == 'posix':
    print("This is a Mac or Linux environment.")
    rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# This is a Mac or Linux environment.

# %%
welfare = pd.read_csv('../data/KC_485_DMSTC_MCST_OLDLSR_2023.csv')
welfare.head()
# Out:
#                        ID LCLAS_NM MLSFC_NM       FCLTY_NM CTPRVN_NM  \
# 0  KC485PC23N000000000001     문화시설      복지관     1004가족복지센터      전라북도
# 1  KC485PC23N000000000002     문화시설      복지관   1004가족재가복지센터       경기도
# 2  KC485PC23N000000000003     문화시설      복지관  1004엔젤스방문요양센터       경기도
# 3  KC485PC23N000000000004     문화시설      복지관   100세고성재가복지센터      경상남도
# 4  KC485PC23N000000000005     문화시설      복지관     100세노인복지센터      경상남도
#
#   SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM   ADSTRD_CD ADSTRD_NM  ...    FCLTY_LO  \
# 0       익산시    5214011400        모현동1가  5214061000       모현동  ...  126.946306
# 1       화성시    4159025325      봉담읍 와우리  4159025300       봉담읍  ...  126.972771
# 2  고양시 일산서구    4128710500          덕이동  4128760000       덕이동  ...  126.751049
# 3       고성군    4882025021      고성읍 성내리  4882025000       고성읍  ...  128.321049
# 4       진주시    4817012500          신안동  4817071500       신안동  ...  128.071955
#
#     FCLTY_LA  OPER_INSTT_NM TEL_NO         LC_LO         LC_LA  LAST_CHG_DE  \
# 0  35.949725            NaN    NaN  9.500649e+05  1.772699e+06     20240906
# 1  37.215112            NaN    NaN  9.532215e+05  1.913051e+06     20240906
# 2  37.699774            NaN    NaN  9.339764e+05  1.966954e+06     20240906
# 3  34.974063            NaN    NaN  1.074947e+06  1.664660e+06     20240906
# 4  35.185477            NaN    NaN  1.052074e+06  1.687947e+06     20240906
#
#    ORIGIN_NM                        FILE_NM   BASE_DE
# 0         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 1         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 2         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 3         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 4         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
#
# [5 rows x 24 columns]

# %%
welfare = welfare[welfare['CTPRVN_NM'].str.contains('서울')]
welfare['MLSFC_NM'].value_counts()
# Out:
# MLSFC_NM
# 노인정/노인회관    1492
# 복지관         1195
# 보육원/양로원      318
# 마을/새마을회관      51
# Name: count, dtype: int64

# %%
welfare.drop(columns=['ID', 'LEGALDONG_CD', 'OPER_INSTT_NM', 'TEL_NO', "ORIGIN_NM", "LAST_CHG_DE", "FILE_NM",
                        'BASE_DE', 'LCLAS_NM', 'ADSTRD_CD', 'LEGALDONG_NM', 'RDNMADR_CD', 'ADSTRD_NM', 'GID_CD', 
                        "ZIP_NO", "LC_LO", "LC_LA"], inplace=True)
welfare.reset_index(drop=True, inplace=True)
welfare.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
import requests
import json

def convert_name(name):
    
    path = '/v2/local/search/keyword.json'
    api_host = 'https://dapi.kakao.com'
    api_key = '275fa9c9b83625900bee1dc000fd7dcb'
    url = api_host+path
    
    header = {
        "Authorization" : f'KakaoAK {api_key}'
    }
    
    body = {
    "format" : "json",
    'query' : name
    }

    try:
        response = requests.get(url=url, params=body, headers=header, timeout=10)  # 10초 타임아웃
        response.raise_for_status()  # HTTP 오류가 발생하면 예외 발생
    except requests.exceptions.Timeout:
        print("Request timed out")
        return {}
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return {}

    parsed_data = json.loads(response.text)

    return parsed_data

# %%
name_list = [] 
address_list = []
x_list = []
y_list = []
idx_list = []
null_idx_list = []
multi_idx_list = []

for idx, val in welfare.iterrows():
    name = val['FCLTY_NM']
    gu = val['SIGNGU_NM']
    data = convert_name('서울 '+gu+" "+name)
    count = data['meta']['total_count']
    
    if count == 1:
        place_name = data['documents'][0]['place_name']
        address_name = data['documents'][0]['road_address_name']
        x_value = data['documents'][0]['x']
        y_value = data['documents'][0]['y']
        
        name_list.append(place_name), address_list.append(address_name), x_list.append(x_value), y_list.append(y_value)
        idx_list.append(idx)
    elif count == 0:
        addr = val['RDNMADR_NM']
        data = convert_name(addr)
        count = data['meta']['total_count']
        
        if count == 0:
            null_idx_list.append(idx)
        
        elif count == 1:
            place_name = data['documents'][0]['place_name']
            address_name = data['documents'][0]['road_address_name']
            x_value = data['documents'][0]['x']
            y_value = data['documents'][0]['y']
            
            name_list.append(place_name), address_list.append(address_name), x_list.append(x_value), y_list.append(y_value)
            idx_list.append(idx)            
        
        else:
            added_to_list = False
            documents = data['documents']
            for i in range(len(documents)):
                category_name = documents[i]['category_name']
                keywords = ['사회복지', '노인복지', '노인정', '노인회', '요양', '마을회관', '동행정복지센터', '협회', '행정기관', '문화시설']
                if any(keyword in category_name for keyword in keywords) == True:
                    place_name = documents[i]['place_name']
                    address_name = documents[i]['road_address_name']
                    x_value = documents[i]['x']
                    y_value = documents[i]['y']
                    name_list.append(place_name), address_list.append(address_name), x_list.append(x_value), y_list.append(y_value), idx_list.append(idx)
                    added_to_list = True
                    break
            if added_to_list == False:
                null_idx_list.append(idx)
            
    else:
        added_to_list = False
        documents = data['documents']
        for i in range(len(documents)):
            category_name = documents[i]['category_name']
            keywords = ['사회복지', '노인복지', '노인정', '노인회', '요양', '마을회관', '동행정복지센터', '협회', '행정기관', '문화시설']
            if any(keyword in category_name for keyword in keywords) == True:
                place_name = documents[i]['place_name']
                address_name = documents[i]['road_address_name']
                x_value = documents[i]['x']
                y_value = documents[i]['y']
                name_list.append(place_name), address_list.append(address_name), x_list.append(x_value), y_list.append(y_value), idx_list.append(idx)
                added_to_list = True
                break
        if added_to_list == False:
            multi_idx_list.append(idx)
        
len(idx_list), len(null_idx_list), len(multi_idx_list)
# Out:
# (2568, 475, 13)

# %%
len(name_list), len(address_list), len(x_list), len(y_list)
# Out:
# (2568, 2568, 2568, 2568)

# %%
welfare.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
result = welfare.loc[idx_list]
result.loc[idx_list, 'FCLTY_NM'] = name_list
result.loc[idx_list, 'RDNMADR_NM'] = address_list
result.loc[idx_list, 'FCLTY_LO'] = x_list
result.loc[idx_list, 'FCLTY_LA'] = y_list
# Out:
# /var/folders/76/295r32t542b3jtvsn34n34s00000gn/T/ipykernel_5502/3652260772.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['127.077066688023', '126.866935742365', '127.00861219666437', '127.094448962354', '126.962831241502', '126.99573994637', '126.825572260256', '126.82484861335737', '126.931456767672', '126.957617005745', '126.85017417033', '126.999272559795', '126.91256490244425', '127.08958075026007', '127.135299206571', '127.036999601764', '127.135299206571', '126.876149827249', '127.133256764435', '126.87397119177422', '127.140413017684', '127.151129173894', '127.060380107015', '127.125769474647', '127.124753390553', '127.119055415614', '127.106904080388', '127.080418159479', '126.86081283646', '126.925218515947', '126.884110707201', '126.884110707201', '126.882503111506', '126.886246947822', '126.8840488747035', '126.986642790239', '126.887626283303', '127.069764065704', '126.888706091182', '126.88450905328021', '126.891779471154', '126.85290656632', '126.853500321319', '126.862529048784', '126.862771591897', '126.84002734154', '126.857883288474', '127.066127589469', '127.073553845097', '127.073553845097', '127.013463342495', '126.857883288474', '127.028963975679', '126.857883288474', '126.957229589082', '127.064573277674', '127.085880660311', '127.022343480371', '127.142313041411', '127.10644999188537', '127.068444379074', '126.85476200715489', '126.85476200715489', '127.037092094529', '127.011043679178', '126.8444311394438', '127.038807779997', '126.92033878914593', '126.984789021037', '126.97308861521', '126.97485835152985', '126.911383295128', '126.913970574732', '126.911383295128', '126.931511427799', '126.849632913696', '126.946575845475', '127.046099668447', '127.048793600718', '127.106945221301', '127.10542621686061', '127.04639574334357', '127.031883233204', '127.052163475052', '127.093478942574', '127.082425751929', '127.023520673757', '127.106950626907', '127.043223980987', '127.073513949191', '127.074590804634', '127.07460436682', '127.052163475052', '127.051269785304', '127.144738024061', '127.14434676784754', '127.12569454854', '127.12569454854', '127.12247509202452', '127.13310158293372', '127.142916045195', '127.136548315822', '127.123838040762', '127.154226268616', '127.142736252777', '127.13914141751258', '127.153710975763', '127.12977158084269', '127.142517511635', '127.1357103581549', '127.134335566545', '127.02971806364673', '127.02981108488086', '127.013218067629', '126.960207573419', '127.018698209755', '127.018698209755', '127.01815829490916', '127.039092190282', '127.039092190282', '127.015455563235', '126.873259560812', '126.85155537898821', '126.80868606488674', '126.841596088348', '126.84751606359804', '126.812587816921', '126.840568160761', '126.863052709833', '126.81241561053753', '126.83262894555952', '126.84498240702816', '126.82392112693964', '126.85298846791015', '126.832660674211', '127.177109378763', '127.133220960533', '127.133220960533', '126.850888921574', '126.852894612526', '126.855383223754', '126.852850275224', '126.853998517065', '126.853998517065', '127.048672718377', '126.798798673298', '126.912784158139', '127.14674787933', '127.14674787933', '127.141026286779', '127.14674787933', '127.14674787933', '127.02971806364673', '126.99271757410703', '126.8897180850707', '127.094029756113', '126.911655942044', '127.142671329683', '127.02971806364673', '127.02285264110027', '127.02971806364673', '126.99271757410703', '126.91124788862305', '127.00030548397113', '126.91124788862305', '127.094029756113', '127.08992891070606', '127.02285264110027', '126.91124788862305', '126.91124788862305', '127.08992891070606', '126.91124788862305', '126.92144534432894', '126.83960102513358', '126.84587249467661', '127.123498200791', '127.066079193801', '127.075320979419', '127.07666464263717', '127.07666464263717', '127.050879505193', '126.95807542179517', '127.084893770764', '127.02311419497', '127.080445571263', ...
#   result.loc[idx_list, 'FCLTY_LO'] = x_list
# /var/folders/76/295r32t542b3jtvsn34n34s00000gn/T/ipykernel_5502/3652260772.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['37.6061293100042', '37.5322915786611', '37.552875682542634', '37.5905214299219', '37.5516240661188', '37.559108119904', '37.5304068967832', '37.5316789391687', '37.4971065945497', '37.486696023974', '37.5487588864067', '37.5282291414644', '37.55610163068798', '37.558827340355634', '37.5043579566015', '37.5985866601962', '37.5043579566015', '37.505537316312', '37.5514610181891', '37.519883494567075', '37.5470017954604', '37.4958945433176', '37.5945306633255', '37.4947673712718', '37.5011980265485', '37.4966520253096', '37.4955752306282', '37.5528206802801', '37.5334350985778', '37.4748911595288', '37.4880271323831', '37.4880271323831', '37.4864037309011', '37.4870705364627', '37.484138322178076', '37.4947434622152', '37.5203513810206', '37.6664421914999', '37.4726747586184', '37.48266832753308', '37.47687631793', '37.5645558927738', '37.5642214607063', '37.5612302006836', '37.559814116817', '37.572341758629', '37.5258695092035', '37.6582399520829', '37.6614772866332', '37.6614772866332', '37.5630700129664', '37.5258695092035', '37.650594778311', '37.5258695092035', '37.5394911181391', '37.6562748706238', '37.5595635011006', '37.5959999949575', '37.4934286264934', '37.5070832831161', '37.6610803263238', '37.4984679973573', '37.4984679973573', '37.579602720288', '37.6412320904471', '37.54276973219396', '37.6133776300285', '37.57422525873819', '37.5800715796048', '37.5457045852823', '37.54589688815525', '37.6220533803323', '37.6219697011912', '37.6220533803323', '37.5808131302147', '37.5680755609015', '37.4881692002959', '37.4849827166238', '37.503405424455', '37.4792210036828', '37.48681786896221', '37.51031349488908', '37.5023696364366', '37.5159063236131', '37.4847384882994', '37.4910934149174', '37.5081488434808', '37.4869795812547', '37.5098047295508', '37.4919714713874', '37.4923311992532', '37.4923239826329', '37.5159063236131', '37.4744162541072', '37.5452522405455', '37.551260574150874', '37.5283172283127', '37.5283172283127', '37.52918557201198', '37.53610547071239', '37.5511073429335', '37.5542972013149', '37.5467860822042', '37.5523725280271', '37.5565225533969', '37.53438931174738', '37.5615561570186', '37.53992310873763', '37.5486318827471', '37.55215559576524', '37.542179513054', '37.63769430128344', '37.62664269500478', '37.6481730474465', '37.5567156505561', '37.6357342165971', '37.6357342165971', '37.62848677033738', '37.6287591955972', '37.6287591955972', '37.6459815833851', '37.5473596415946', '37.550158979430506', '37.57098688527256', '37.5456996142118', '37.55815468570673', '37.574204285567', '37.569282713293', '37.5292669851735', '37.57019819348311', '37.56007616734461', '37.54157663372401', '37.559000326910606', '37.530928945443506', '37.5600590933957', '37.562114428888', '37.49315901607', '37.49315901607', '37.4818954586079', '37.4899854161108', '37.4871340980078', '37.4872246751725', '37.4991265922897', '37.4991265922897', '37.4809505719706', '37.5830617730737', '37.609737015371', '37.4921987332083', '37.4921987332083', '37.4970855514284', '37.4921987332083', '37.4921987332083', '37.63769430128344', '37.43611067540884', '37.48253274714113', '37.5849076810081', '37.552411369116', '37.489770107233', '37.63769430128344', '37.565074186695895', '37.63769430128344', '37.43611067540884', '37.54913863808177', '37.53484069086598', '37.54913863808177', '37.5849076810081', '37.54716816503001', '37.565074186695895', '37.54913863808177', '37.54913863808177', '37.54716816503001', '37.54913863808177', '37.51112721177526', '37.49236209021515', '37.51758865378507', '37.4916594925884', '37.6471092400305', '37.6291885200206', '37.662361871300746', '37.662361871300746', '37.5440289409427', '37.54446764248579', '37.6711786354867', '37.6495401172632', '37.5656868963763', '37.6759949729942', '37.6487790898889', '37.5811 ...
#   result.loc[idx_list, 'FCLTY_LA'] = y_list

# %%
result.reset_index(drop=True, inplace=True)
result
# Out:
#       MLSFC_NM          FCLTY_NM CTPRVN_NM SIGNGU_NM              RDNMADR_NM  \
# 0          복지관         1318상상발전소     서울특별시       중랑구         서울 중랑구 중랑역로 142
# 1     노인정/노인회관  대원2차3차칸타빌아파트 노인정     서울특별시       강서구         서울 양천구 목동중앙로 11
# 2          복지관          안토재가복지센터     서울특별시        중구            서울 중구 다산로 93
# 3          복지관        A+대한방문요양센터     서울특별시       중랑구        서울 중랑구 상봉로12길 16
# 4          복지관       A+행복한방문요양센터     서울특별시       용산구       서울 용산구 만리재로 138-1
# ...        ...               ...       ...       ...                     ...
# 2563       복지관              희망의집     서울특별시       강서구        서울 강서구 강서로34길 36
# 2564       복지관        희망의집지역아동센터     서울특별시       강북구        서울 강북구 삼양로 280-1
# 2565       복지관             희망의학교     서울특별시       광진구         서울 광진구 천호대로 622
# 2566       복지관       희망 재가노인복지센터     서울특별시       강서구  경기 부천시 오정구 고리울로51번길 34
# 2567       복지관        흰돌재가장기요양센터     서울특별시       강동구         서울 강동구 구천면로 323
#
#                 FCLTY_LO            FCLTY_LA
# 0       127.077066688023    37.6061293100042
# 1       126.866935742365    37.5322915786611
# 2     127.00861219666437  37.552875682542634
# 3       127.094448962354    37.5905214299219
# 4       126.962831241502    37.5516240661188
# ...                  ...                 ...
# 2563    126.841487920742    37.5433424571914
# 2564  127.01826138600413   37.62849756626493
# 2565    127.086435692246    37.5540760233142
# 2566    126.822155029041    37.5287295433574
# 2567    127.135541717453    37.5483950247313
#
# [2568 rows x 7 columns]

# %%
pop = pd.read_excel('../data/자치구별+고령인구(추계인구)_20241019165325.xlsx')
pop.head()
# Out:
#    자치구별(1)  자치구별(2)     2023  2023.1  2023.2
# 0  자치구별(1)  자치구별(2)     고령인구    고령인구    고령인구
# 1  자치구별(1)  자치구별(2)       소계      남자      여자
# 2       합계       소계  1691853  749118  942735
# 3      NaN      종로구    27187   11986   15201
# 4      NaN       중구    24374   10637   13737

# %%
pop.drop(index=[0, 1, 2], columns=['자치구별(1)'], inplace=True)
pop.columns = ["구별", "노령인구", "노령인구_남자", "노령인구_여자"]
pop.reset_index(drop=True, inplace=True)
pop.head()
# Out:
#     구별   노령인구 노령인구_남자 노령인구_여자
# 0  종로구  27187   11986   15201
# 1   중구  24374   10637   13737
# 2  용산구  37740   16395   21345
# 3  성동구  47907   21034   26873
# 4  광진구  55697   24952   30745

# %%
pop_result = pop[['구별', '노령인구']]
pop_result.head()
# Out:
#     구별   노령인구
# 0  종로구  27187
# 1   중구  24374
# 2  용산구  37740
# 3  성동구  47907
# 4  광진구  55697

# %%
cnt = result['SIGNGU_NM'].value_counts().reset_index()
cnt.rename(columns={"SIGNGU_NM" : "구별", "count" : "복지시설개수"}, inplace=True)
cnt.head()
# Out:
#      구별  복지시설개수
# 0   강서구     161
# 1   양천구     140
# 2  영등포구     134
# 3   노원구     131
# 4   송파구     127

# %%
cnt_result = cnt.merge(right=pop_result, left_on='구별', right_on='구별')
cnt_result.head()
# Out:
#      구별  복지시설개수    노령인구
# 0   강서구     161   98380
# 1   양천구     140   73126
# 2  영등포구     134   70566
# 3   노원구     131   92104
# 4   송파구     127  104433

# %%
cnt_result['복지시설개수(10K)'] = cnt_result['복지시설개수'] / cnt_result['노령인구'] * 10000
cnt_result.head()
# Out:
#      구별  복지시설개수    노령인구 복지시설개수(10K)
# 0   강서구     161   98380   16.365115
# 1   양천구     140   73126   19.145037
# 2  영등포구     134   70566   18.989315
# 3   노원구     131   92104   14.223052
# 4   송파구     127  104433   12.160907

# %%
cnt_result.to_csv('../data/output/welfare_f.csv', index=False)
